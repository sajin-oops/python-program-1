# %%
pip install youtube-transcript-api
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from youtube_transcript_api import YouTubeTranscriptApi

ytt_api = YouTubeTranscriptApi()
ytt_api.fetch("0OnyVmj6yxY")
# Out:
# FetchedTranscript(snippets=[FetchedTranscriptSnippet(text='[Music]', start=0.0, duration=3.84), FetchedTranscriptSnippet(text='Something huge just dropped in the AI', start=1.6, duration=4.8), FetchedTranscriptSnippet(text='world and it did not come from OpenAI or', start=3.84, duration=5.6), FetchedTranscriptSnippet(text='Google. A tiny startup in Singapore just', start=6.4, duration=7.199), FetchedTranscriptSnippet(text='unveiled a new AI agent called HRM', start=9.44, duration=6.239), FetchedTranscriptSnippet(text='and it might be the biggest breakthrough', start=13.599, duration=4.961), FetchedTranscriptSnippet(text='in reasoning we have seen in years. It', start=15.679, duration=4.961), FetchedTranscriptSnippet(text='is not bigger. It is not trained on more', start=18.56, duration=5.04), FetchedTranscriptSnippet(text='data. Instead, it is built different.', start=20.64, duration=5.76), FetchedTranscriptSnippet(text='And somehow this brainspired model is', start=23.6, duration=5.
# ...
